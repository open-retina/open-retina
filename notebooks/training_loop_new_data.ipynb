# %% [markdown]
# This notebook is just a reproduction of the main Hoefling 2022 model training loop on the new `.h5` data export srategy used past March 2024.

# %%
import collections.abc
import os
import pickle
import pprint

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
from openretina.h5_handling import load_h5_into_dict
from openretina.hoefling_2022_configs import model_config, trainer_config
from openretina.hoefling_2022_data_io import natmov_dataloaders_v2
from openretina.hoefling_2022_models import SFB3d_core_SxF3d_readout
from openretina.misc import CustomPrettyPrinter
from openretina.neuron_data_io import make_final_responses
from openretina.plotting import play_stimulus
from openretina.training import standard_early_stop_trainer as trainer

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

pp = CustomPrettyPrinter(indent=4)

# %%
# !ls /Data/fd_export
# Out:
# 2024-01-11_movies_dict_8c18928.pkl
# 2024-01-11_movies_dict_c285329.pkl
# 2024-01-11_neuron_data_stim_8c18928_responses_99c71a0.pkl
# 2024-01-11_neuron_data_stim_c285329_responses_0698360.pkl
# 2024-01-11_neuron_data_stim_c285329_responses_483c12d.pkl
# 2024-03-22_neuron_data_stim_c285329_responses_483c12d.h5
# 2024-03-25_neuron_data_responses_484c12d_djimaging.h5
# 2024-03-27_neuron_data_stim_c285329_responses_483c12d.h5
# 2024-03-28_neuron_data_responses_484c12d_djimaging.h5
# figures
# models
# movies_8c18928.pkl
# movies_c285329.pkl

# %%
base_folder = "/Data/fd_export"
data_path = os.path.join(
    base_folder, "2024-03-28_neuron_data_responses_484c12d_djimaging.h5"
)
movies_path = os.path.join(base_folder, "2024-01-11_movies_dict_8c18928.pkl")
responses = load_h5_into_dict(data_path)
stim_dataloaders_dict = make_final_responses(responses)
movies_dict = pickle.load(open(movies_path, "rb"))
# Out:
# Loading HDF5 file contents:   0%|          | 0/1474 [00:00<?, ?item/s]
# Upsampling traces to get final responses:   0%|          | 0/67 [00:00<?, ?it/s]

# %%
pp.pprint(stim_dataloaders_dict)
# Out:
# {   'session_1_ventral1_20200226': {   'chirp_raw_traces': numpy.ndarray(shape=(131, 1501)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(131, 1501)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(131, 1501)),
#                                        'chirp_spikes': numpy.ndarray(shape=(131, 1501)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(131, 1501)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(131, 10)),
#                                        'date': '2020-02-26',
#                                        'exp_num': 1,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'left',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(131,)),
#                                        'group_confidences': numpy.ndarray(shape=(131, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(131, 1017)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(131, 1017)),
#                                        'mb_spike_times': numpy.ndarray(shape=(131, 1017)),
#                                        'mb_spikes': numpy.ndarray(shape=(131, 1017)),
#                                        'mb_traces_times': numpy.ndarray(shape=(131, 1017)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(131, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(131, 5036)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(131, 5036)),
#                                        'natural_spike_times': numpy.ndarray(shape=(131, 5036)),
#                                        'natural_spikes': numpy.ndarray(shape=(131, 5036)),
#                                        'natural_traces_times': numpy.ndarray(shape=(131, 5036)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(131, 123)),
#                                        'responses_final': numpy.ndarray(shape=(131, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(131,)),
#                                        'scan_sequence_idx': 18,
#                                        'stim_id': 5},
#     'session_1_ventral1_20200528': {   'chirp_raw_traces': numpy.ndarray(shape=(105, 1579)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(105, 1579)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(105, 1579)),
#                                        'chirp_spikes': numpy.ndarray(shape=(105, 1579)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(105, 1579)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(105, 10)),
#                                        'date': '2020-05-28',
#                                        'exp_num': 1,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'left',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(105,)),
#                                        'group_confidences': numpy.ndarray(shape=(105, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(105, 987)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(105, 987)),
#                                        'mb_spike_times': numpy.ndarray(shape=(105, 987)),
#                                        'mb_spikes': numpy.ndarray(shape=(105, 987)),
#                                        'mb_traces_times': numpy.ndarray(shape=(105, 987)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(105, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(105, 5119)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(105, 5119)),
#                                        'natural_spike_times': numpy.ndarray(shape=(105, 5119)),
#                                        'natural_spikes': numpy.ndarray(shape=(105, 5119)),
#                                        'natural_traces_times': numpy.ndarray(shape=(105, 5119)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(105, 123)),
#                                        'responses_final': numpy.ndarray(shape=(105, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(105,)),
#                                        'scan_sequence_idx': 4,
#                                        'stim_id': 5},
#     'session_1_ventral1_20200707': {   'chirp_raw_traces': numpy.ndarray(shape=(171, 1663)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(171, 1663)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(171, 1663)),
#                                        'chirp_spikes': numpy.ndarray(shape=(171, 1663)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(171, 1663)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(171, 10)),
#                                        'date': '2020-07-07',
#                                        'exp_num': 1,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'left',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(171,)),
#                                        'group_confidences': numpy.ndarray(shape=(171, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(171, 1047)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(171, 1047)),
#                                        'mb_spike_times': numpy.ndarray(shape=(171, 1047)),
#                                        'mb_spikes': numpy.ndarray(shape=(171, 1047)),
#                                        'mb_traces_times': numpy.ndarray(shape=(171, 1047)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(171, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(171, 5193)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(171, 5193)),
#                                        'natural_spike_times': numpy.ndarray(shape=(171, 5193)),
#                                        'natural_spikes': numpy.ndarray(shape=(171, 5193)),
#                                        'natural_traces_times': numpy.ndarray(shape=(171, 5193)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(171, 123)),
#                                        'responses_final': numpy.ndarray(shape=(171, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(171,)),
#                                        'scan_sequence_idx': 16,
#                                        'stim_id': 5},
#     'session_1_ventral1_20201021': {   'chirp_raw_traces': numpy.ndarray(shape=(133, 1476)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(133, 1476)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(133, 1476)),
#                                        'chirp_spikes': numpy.ndarray(shape=(133, 1476)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(133, 1476)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(133, 10)),
#                                        'date': '2020-10-21',
#                                        'exp_num': 1,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'left',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(133,)),
#                                        'group_confidences': numpy.ndarray(shape=(133, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(133, 1003)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(133, 1003)),
#                                        'mb_spike_times': numpy.ndarray(shape=(133, 1003)),
#                                        'mb_spikes': numpy.ndarray(shape=(133, 1003)),
#                                        'mb_traces_times': numpy.ndarray(shape=(133, 1003)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(133, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(133, 5069)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(133, 5069)),
#                                        'natural_spike_times': numpy.ndarray(shape=(133, 5069)),
#                                        'natural_spikes': numpy.ndarray(shape=(133, 5069)),
#                                        'natural_traces_times': numpy.ndarray(shape=(133, 5069)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(133, 123)),
#                                        'responses_final': numpy.ndarray(shape=(133, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(133,)),
#                                        'scan_sequence_idx': 3,
#                                        'stim_id': 5},
#     'session_1_ventral1_20201030': {   'chirp_raw_traces': numpy.ndarray(shape=(105, 1539)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(105, 1539)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(105, 1539)),
#                                        'chirp_spikes': numpy.ndarray(shape=(105, 1539)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(105, 1539)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(105, 10)),
#                                        'date': '2020-10-30',
#                                        'exp_num': 1,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'left',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(105,)),
#                                        'group_confidences': numpy.ndarray(shape=(105, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(105, 1053)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(105, 1053)),
#                                        'mb_spike_times': numpy.ndarray(shape=(105, 1053)),
#                                        'mb_spikes': numpy.ndarray(shape=(105, 1053)),
#                                        'mb_traces_times': numpy.ndarray(shape=(105, 1053)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(105, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(105, 5103)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(105, 5103)),
#                                        'natural_spike_times': numpy.ndarray(shape=(105, 5103)),
#                                        'natural_spikes': numpy.ndarray(shape=(105, 5103)),
#                                        'natural_traces_times': numpy.ndarray(shape=(105, 5103)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(105, 123)),
#                                        'responses_final': numpy.ndarray(shape=(105, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(105,)),
#                                        'scan_sequence_idx': 8,
#                                        'stim_id': 5},
#     'session_1_ventral1_20210929': {   'chirp_raw_traces': numpy.ndarray(shape=(120, 1520)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(120, 1520)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(120, 1520)),
#                                        'chirp_spikes': numpy.ndarray(shape=(120, 1520)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(120, 1520)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(120, 10)),
#                                        'date': '2021-09-29',
#                                        'exp_num': 1,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'left',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(120,)),
#                                        'group_confidences': numpy.ndarray(shape=(120, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(120, 1070)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(120, 1070)),
#                                        'mb_spike_times': numpy.ndarray(shape=(120, 1070)),
#                                        'mb_spikes': numpy.ndarray(shape=(120, 1070)),
#                                        'mb_traces_times': numpy.ndarray(shape=(120, 1070)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(120, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(120, 5256)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(120, 5256)),
#                                        'natural_spike_times': numpy.ndarray(shape=(120, 5256)),
#                                        'natural_spikes': numpy.ndarray(shape=(120, 5256)),
#                                        'natural_traces_times': numpy.ndarray(shape=(120, 5256)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(120, 123)),
#                                        'responses_final': numpy.ndarray(shape=(120, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(120,)),
#                                        'scan_sequence_idx': 7,
#                                        'stim_id': 5},
#     'session_1_ventral1_20210930': {   'chirp_raw_traces': numpy.ndarray(shape=(107, 1526)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(107, 1526)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(107, 1526)),
#                                        'chirp_spikes': numpy.ndarray(shape=(107, 1526)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(107, 1526)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(107, 10)),
#                                        'date': '2021-09-30',
#                                        'exp_num': 1,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'left',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(107,)),
#                                        'group_confidences': numpy.ndarray(shape=(107, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(107, 1032)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(107, 1032)),
#                                        'mb_spike_times': numpy.ndarray(shape=(107, 1032)),
#                                        'mb_spikes': numpy.ndarray(shape=(107, 1032)),
#                                        'mb_traces_times': numpy.ndarray(shape=(107, 1032)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(107, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(107, 5075)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(107, 5075)),
#                                        'natural_spike_times': numpy.ndarray(shape=(107, 5075)),
#                                        'natural_spikes': numpy.ndarray(shape=(107, 5075)),
#                                        'natural_traces_times': numpy.ndarray(shape=(107, 5075)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(107, 123)),
#                                        'responses_final': numpy.ndarray(shape=(107, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(107,)),
#                                        'scan_sequence_idx': 5,
#                                        'stim_id': 5},
#     'session_1_ventral2_20200302': {   'chirp_raw_traces': numpy.ndarray(shape=(121, 1596)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(121, 1596)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(121, 1596)),
#                                        'chirp_spikes': numpy.ndarray(shape=(121, 1596)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(121, 1596)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(121, 10)),
#                                        'date': '2020-03-02',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(121,)),
#                                        'group_confidences': numpy.ndarray(shape=(121, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(121, 998)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(121, 998)),
#                                        'mb_spike_times': numpy.ndarray(shape=(121, 998)),
#                                        'mb_spikes': numpy.ndarray(shape=(121, 998)),
#                                        'mb_traces_times': numpy.ndarray(shape=(121, 998)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(121, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(121, 5078)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(121, 5078)),
#                                        'natural_spike_times': numpy.ndarray(shape=(121, 5078)),
#                                        'natural_spikes': numpy.ndarray(shape=(121, 5078)),
#                                        'natural_traces_times': numpy.ndarray(shape=(121, 5078)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(121, 123)),
#                                        'responses_final': numpy.ndarray(shape=(121, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(121,)),
#                                        'scan_sequence_idx': 3,
#                                        'stim_id': 5},
#     'session_1_ventral2_20200707': {   'chirp_raw_traces': numpy.ndarray(shape=(159, 1554)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(159, 1554)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(159, 1554)),
#                                        'chirp_spikes': numpy.ndarray(shape=(159, 1554)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(159, 1554)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(159, 10)),
#                                        'date': '2020-07-07',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(159,)),
#                                        'group_confidences': numpy.ndarray(shape=(159, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(159, 972)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(159, 972)),
#                                        'mb_spike_times': numpy.ndarray(shape=(159, 972)),
#                                        'mb_spikes': numpy.ndarray(shape=(159, 972)),
#                                        'mb_traces_times': numpy.ndarray(shape=(159, 972)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(159, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(159, 5109)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(159, 5109)),
#                                        'natural_spike_times': numpy.ndarray(shape=(159, 5109)),
#                                        'natural_spikes': numpy.ndarray(shape=(159, 5109)),
#                                        'natural_traces_times': numpy.ndarray(shape=(159, 5109)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(159, 123)),
#                                        'responses_final': numpy.ndarray(shape=(159, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(159,)),
#                                        'scan_sequence_idx': 8,
#                                        'stim_id': 5},
#     'session_1_ventral2_20201021': {   'chirp_raw_traces': numpy.ndarray(shape=(126, 1536)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(126, 1536)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(126, 1536)),
#                                        'chirp_spikes': numpy.ndarray(shape=(126, 1536)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(126, 1536)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(126, 10)),
#                                        'date': '2020-10-21',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(126,)),
#                                        'group_confidences': numpy.ndarray(shape=(126, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(126, 996)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(126, 996)),
#                                        'mb_spike_times': numpy.ndarray(shape=(126, 996)),
#                                        'mb_spikes': numpy.ndarray(shape=(126, 996)),
#                                        'mb_traces_times': numpy.ndarray(shape=(126, 996)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(126, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(126, 5083)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(126, 5083)),
#                                        'natural_spike_times': numpy.ndarray(shape=(126, 5083)),
#                                        'natural_spikes': numpy.ndarray(shape=(126, 5083)),
#                                        'natural_traces_times': numpy.ndarray(shape=(126, 5083)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(126, 123)),
#                                        'responses_final': numpy.ndarray(shape=(126, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(126,)),
#                                        'scan_sequence_idx': 15,
#                                        'stim_id': 5},
#     'session_1_ventral2_20201022': {   'chirp_raw_traces': numpy.ndarray(shape=(133, 1555)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(133, 1555)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(133, 1555)),
#                                        'chirp_spikes': numpy.ndarray(shape=(133, 1555)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(133, 1555)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(133, 10)),
#                                        'date': '2020-10-22',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(133,)),
#                                        'group_confidences': numpy.ndarray(shape=(133, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(133, 1003)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(133, 1003)),
#                                        'mb_spike_times': numpy.ndarray(shape=(133, 1003)),
#                                        'mb_spikes': numpy.ndarray(shape=(133, 1003)),
#                                        'mb_traces_times': numpy.ndarray(shape=(133, 1003)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(133, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(133, 5083)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(133, 5083)),
#                                        'natural_spike_times': numpy.ndarray(shape=(133, 5083)),
#                                        'natural_spikes': numpy.ndarray(shape=(133, 5083)),
#                                        'natural_traces_times': numpy.ndarray(shape=(133, 5083)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(133, 123)),
#                                        'responses_final': numpy.ndarray(shape=(133, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(133,)),
#                                        'scan_sequence_idx': 6,
#                                        'stim_id': 5},
#     'session_1_ventral2_20201030': {   'chirp_raw_traces': numpy.ndarray(shape=(125, 1517)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(125, 1517)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(125, 1517)),
#                                        'chirp_spikes': numpy.ndarray(shape=(125, 1517)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(125, 1517)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(125, 10)),
#                                        'date': '2020-10-30',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(125,)),
#                                        'group_confidences': numpy.ndarray(shape=(125, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(125, 967)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(125, 967)),
#                                        'mb_spike_times': numpy.ndarray(shape=(125, 967)),
#                                        'mb_spikes': numpy.ndarray(shape=(125, 967)),
#                                        'mb_traces_times': numpy.ndarray(shape=(125, 967)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(125, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(125, 5054)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(125, 5054)),
#                                        'natural_spike_times': numpy.ndarray(shape=(125, 5054)),
#                                        'natural_spikes': numpy.ndarray(shape=(125, 5054)),
#                                        'natural_traces_times': numpy.ndarray(shape=(125, 5054)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(125, 123)),
#                                        'responses_final': numpy.ndarray(shape=(125, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(125,)),
#                                        'scan_sequence_idx': 12,
#                                        'stim_id': 5},
#     'session_1_ventral2_20201117': {   'chirp_raw_traces': numpy.ndarray(shape=(114, 1698)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(114, 1698)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(114, 1698)),
#                                        'chirp_spikes': numpy.ndarray(shape=(114, 1698)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(114, 1698)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(114, 10)),
#                                        'date': '2020-11-17',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(114,)),
#                                        'group_confidences': numpy.ndarray(shape=(114, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(114, 1030)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(114, 1030)),
#                                        'mb_spike_times': numpy.ndarray(shape=(114, 1030)),
#                                        'mb_spikes': numpy.ndarray(shape=(114, 1030)),
#                                        'mb_traces_times': numpy.ndarray(shape=(114, 1030)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(114, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(114, 5179)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(114, 5179)),
#                                        'natural_spike_times': numpy.ndarray(shape=(114, 5179)),
#                                        'natural_spikes': numpy.ndarray(shape=(114, 5179)),
#                                        'natural_traces_times': numpy.ndarray(shape=(114, 5179)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(114, 123)),
#                                        'responses_final': numpy.ndarray(shape=(114, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(114,)),
#                                        'scan_sequence_idx': 1,
#                                        'stim_id': 5},
#     'session_1_ventral2_20210910': {   'chirp_raw_traces': numpy.ndarray(shape=(122, 1550)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(122, 1550)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(122, 1550)),
#                                        'chirp_spikes': numpy.ndarray(shape=(122, 1550)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(122, 1550)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(122, 10)),
#                                        'date': '2021-09-10',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(122,)),
#                                        'group_confidences': numpy.ndarray(shape=(122, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(122, 1020)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(122, 1020)),
#                                        'mb_spike_times': numpy.ndarray(shape=(122, 1020)),
#                                        'mb_spikes': numpy.ndarray(shape=(122, 1020)),
#                                        'mb_traces_times': numpy.ndarray(shape=(122, 1020)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(122, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(122, 5149)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(122, 5149)),
#                                        'natural_spike_times': numpy.ndarray(shape=(122, 5149)),
#                                        'natural_spikes': numpy.ndarray(shape=(122, 5149)),
#                                        'natural_traces_times': numpy.ndarray(shape=(122, 5149)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(122, 123)),
#                                        'responses_final': numpy.ndarray(shape=(122, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(122,)),
#                                        'scan_sequence_idx': 7,
#                                        'stim_id': 5},
#     'session_1_ventral2_20210921': {   'chirp_raw_traces': numpy.ndarray(shape=(109, 1570)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(109, 1570)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(109, 1570)),
#                                        'chirp_spikes': numpy.ndarray(shape=(109, 1570)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(109, 1570)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(109, 10)),
#                                        'date': '2021-09-21',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(109,)),
#                                        'group_confidences': numpy.ndarray(shape=(109, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(109, 1049)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(109, 1049)),
#                                        'mb_spike_times': numpy.ndarray(shape=(109, 1049)),
#                                        'mb_spikes': numpy.ndarray(shape=(109, 1049)),
#                                        'mb_traces_times': numpy.ndarray(shape=(109, 1049)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(109, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(109, 5051)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(109, 5051)),
#                                        'natural_spike_times': numpy.ndarray(shape=(109, 5051)),
#                                        'natural_spikes': numpy.ndarray(shape=(109, 5051)),
#                                        'natural_traces_times': numpy.ndarray(shape=(109, 5051)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(109, 123)),
#                                        'responses_final': numpy.ndarray(shape=(109, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(109,)),
#                                        'scan_sequence_idx': 7,
#                                        'stim_id': 5},
#     'session_1_ventral2_20210929': {   'chirp_raw_traces': numpy.ndarray(shape=(133, 1568)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(133, 1568)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(133, 1568)),
#                                        'chirp_spikes': numpy.ndarray(shape=(133, 1568)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(133, 1568)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(133, 10)),
#                                        'date': '2021-09-29',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(133,)),
#                                        'group_confidences': numpy.ndarray(shape=(133, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(133, 1012)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(133, 1012)),
#                                        'mb_spike_times': numpy.ndarray(shape=(133, 1012)),
#                                        'mb_spikes': numpy.ndarray(shape=(133, 1012)),
#                                        'mb_traces_times': numpy.ndarray(shape=(133, 1012)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(133, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(133, 6000)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(133, 6000)),
#                                        'natural_spike_times': numpy.ndarray(shape=(133, 6000)),
#                                        'natural_spikes': numpy.ndarray(shape=(133, 6000)),
#                                        'natural_traces_times': numpy.ndarray(shape=(133, 6000)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(133, 123)),
#                                        'responses_final': numpy.ndarray(shape=(133, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(133,)),
#                                        'scan_sequence_idx': 8,
#                                        'stim_id': 5},
#     'session_1_ventral2_20210930': {   'chirp_raw_traces': numpy.ndarray(shape=(112, 1526)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(112, 1526)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(112, 1526)),
#                                        'chirp_spikes': numpy.ndarray(shape=(112, 1526)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(112, 1526)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(112, 10)),
#                                        'date': '2021-09-30',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(112,)),
#                                        'group_confidences': numpy.ndarray(shape=(112, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(112, 1082)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(112, 1082)),
#                                        'mb_spike_times': numpy.ndarray(shape=(112, 1082)),
#                                        'mb_spikes': numpy.ndarray(shape=(112, 1082)),
#                                        'mb_traces_times': numpy.ndarray(shape=(112, 1082)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(112, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(112, 5078)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(112, 5078)),
#                                        'natural_spike_times': numpy.ndarray(shape=(112, 5078)),
#                                        'natural_spikes': numpy.ndarray(shape=(112, 5078)),
#                                        'natural_traces_times': numpy.ndarray(shape=(112, 5078)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(112, 123)),
#                                        'responses_final': numpy.ndarray(shape=(112, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(112,)),
#                                        'scan_sequence_idx': 7,
#                                        'stim_id': 5},
#     'session_1_ventral2_20211130': {   'chirp_raw_traces': numpy.ndarray(shape=(120, 1580)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(120, 1580)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(120, 1580)),
#                                        'chirp_spikes': numpy.ndarray(shape=(120, 1580)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(120, 1580)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(120, 10)),
#                                        'date': '2021-11-30',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL0',
#                                        'group_assignment': numpy.ndarray(shape=(120,)),
#                                        'group_confidences': numpy.ndarray(shape=(120, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(120, 1150)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(120, 1150)),
#                                        'mb_spike_times': numpy.ndarray(shape=(120, 1150)),
#                                        'mb_spikes': numpy.ndarray(shape=(120, 1150)),
#                                        'mb_traces_times': numpy.ndarray(shape=(120, 1150)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(120, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(120, 5199)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(120, 5199)),
#                                        'natural_spike_times': numpy.ndarray(shape=(120, 5199)),
#                                        'natural_spikes': numpy.ndarray(shape=(120, 5199)),
#                                        'natural_traces_times': numpy.ndarray(shape=(120, 5199)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(120, 123)),
#                                        'responses_final': numpy.ndarray(shape=(120, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(120,)),
#                                        'scan_sequence_idx': 9,
#                                        'stim_id': 5},
#     'session_2_ventral1_20200226': {   'chirp_raw_traces': numpy.ndarray(shape=(120, 1498)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(120, 1498)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(120, 1498)),
#                                        'chirp_spikes': numpy.ndarray(shape=(120, 1498)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(120, 1498)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(120, 10)),
#                                        'date': '2020-02-26',
#                                        'exp_num': 1,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'left',
#                                        'field': 'GCL1',
#                                        'group_assignment': numpy.ndarray(shape=(120,)),
#                                        'group_confidences': numpy.ndarray(shape=(120, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(120, 979)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(120, 979)),
#                                        'mb_spike_times': numpy.ndarray(shape=(120, 979)),
#                                        'mb_spikes': numpy.ndarray(shape=(120, 979)),
#                                        'mb_traces_times': numpy.ndarray(shape=(120, 979)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(120, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(120, 5156)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(120, 5156)),
#                                        'natural_spike_times': numpy.ndarray(shape=(120, 5156)),
#                                        'natural_spikes': numpy.ndarray(shape=(120, 5156)),
#                                        'natural_traces_times': numpy.ndarray(shape=(120, 5156)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(120, 123)),
#                                        'responses_final': numpy.ndarray(shape=(120, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(120,)),
#                                        'scan_sequence_idx': 14,
#                                        'stim_id': 5},
#     'session_2_ventral1_20200303': {   'chirp_raw_traces': numpy.ndarray(shape=(131, 1525)),
# ...
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(117, 5093)),
#                                        'natural_spike_times': numpy.ndarray(shape=(117, 5093)),
#                                        'natural_spikes': numpy.ndarray(shape=(117, 5093)),
#                                        'natural_traces_times': numpy.ndarray(shape=(117, 5093)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(117, 123)),
#                                        'responses_final': numpy.ndarray(shape=(117, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(117,)),
#                                        'scan_sequence_idx': 15,
#                                        'stim_id': 5},
#     'session_5_ventral1_20200226': {   'chirp_raw_traces': numpy.ndarray(shape=(101, 1582)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(101, 1582)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(101, 1582)),
#                                        'chirp_spikes': numpy.ndarray(shape=(101, 1582)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(101, 1582)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(101, 10)),
#                                        'date': '2020-02-26',
#                                        'exp_num': 1,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'left',
#                                        'field': 'GCL4',
#                                        'group_assignment': numpy.ndarray(shape=(101,)),
#                                        'group_confidences': numpy.ndarray(shape=(101, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(101, 1011)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(101, 1011)),
#                                        'mb_spike_times': numpy.ndarray(shape=(101, 1011)),
#                                        'mb_spikes': numpy.ndarray(shape=(101, 1011)),
#                                        'mb_traces_times': numpy.ndarray(shape=(101, 1011)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(101, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(101, 5217)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(101, 5217)),
#                                        'natural_spike_times': numpy.ndarray(shape=(101, 5217)),
#                                        'natural_spikes': numpy.ndarray(shape=(101, 5217)),
#                                        'natural_traces_times': numpy.ndarray(shape=(101, 5217)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(101, 123)),
#                                        'responses_final': numpy.ndarray(shape=(101, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(101,)),
#                                        'scan_sequence_idx': 19,
#                                        'stim_id': 5},
#     'session_5_ventral2_20200303': {   'chirp_raw_traces': numpy.ndarray(shape=(119, 1620)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(119, 1620)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(119, 1620)),
#                                        'chirp_spikes': numpy.ndarray(shape=(119, 1620)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(119, 1620)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(119, 10)),
#                                        'date': '2020-03-03',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL4',
#                                        'group_assignment': numpy.ndarray(shape=(119,)),
#                                        'group_confidences': numpy.ndarray(shape=(119, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(119, 988)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(119, 988)),
#                                        'mb_spike_times': numpy.ndarray(shape=(119, 988)),
#                                        'mb_spikes': numpy.ndarray(shape=(119, 988)),
#                                        'mb_traces_times': numpy.ndarray(shape=(119, 988)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(119, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(119, 5088)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(119, 5088)),
#                                        'natural_spike_times': numpy.ndarray(shape=(119, 5088)),
#                                        'natural_spikes': numpy.ndarray(shape=(119, 5088)),
#                                        'natural_traces_times': numpy.ndarray(shape=(119, 5088)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(119, 123)),
#                                        'responses_final': numpy.ndarray(shape=(119, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(119,)),
#                                        'scan_sequence_idx': 1,
#                                        'stim_id': 5},
#     'session_5_ventral2_20210910': {   'chirp_raw_traces': numpy.ndarray(shape=(82, 1606)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(82, 1606)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(82, 1606)),
#                                        'chirp_spikes': numpy.ndarray(shape=(82, 1606)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(82, 1606)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(82, 10)),
#                                        'date': '2021-09-10',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL4',
#                                        'group_assignment': numpy.ndarray(shape=(82,)),
#                                        'group_confidences': numpy.ndarray(shape=(82, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(82, 1021)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(82, 1021)),
#                                        'mb_spike_times': numpy.ndarray(shape=(82, 1021)),
#                                        'mb_spikes': numpy.ndarray(shape=(82, 1021)),
#                                        'mb_traces_times': numpy.ndarray(shape=(82, 1021)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(82, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(82, 5136)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(82, 5136)),
#                                        'natural_spike_times': numpy.ndarray(shape=(82, 5136)),
#                                        'natural_spikes': numpy.ndarray(shape=(82, 5136)),
#                                        'natural_traces_times': numpy.ndarray(shape=(82, 5136)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(82, 123)),
#                                        'responses_final': numpy.ndarray(shape=(82, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(82,)),
#                                        'scan_sequence_idx': 15,
#                                        'stim_id': 5},
#     'session_5_ventral2_20210921': {   'chirp_raw_traces': numpy.ndarray(shape=(108, 1608)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(108, 1608)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(108, 1608)),
#                                        'chirp_spikes': numpy.ndarray(shape=(108, 1608)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(108, 1608)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(108, 10)),
#                                        'date': '2021-09-21',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL4',
#                                        'group_assignment': numpy.ndarray(shape=(108,)),
#                                        'group_confidences': numpy.ndarray(shape=(108, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(108, 1053)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(108, 1053)),
#                                        'mb_spike_times': numpy.ndarray(shape=(108, 1053)),
#                                        'mb_spikes': numpy.ndarray(shape=(108, 1053)),
#                                        'mb_traces_times': numpy.ndarray(shape=(108, 1053)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(108, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(108, 5047)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(108, 5047)),
#                                        'natural_spike_times': numpy.ndarray(shape=(108, 5047)),
#                                        'natural_spikes': numpy.ndarray(shape=(108, 5047)),
#                                        'natural_traces_times': numpy.ndarray(shape=(108, 5047)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(108, 123)),
#                                        'responses_final': numpy.ndarray(shape=(108, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(108,)),
#                                        'scan_sequence_idx': 9,
#                                        'stim_id': 5},
#     'session_5_ventral2_20210929': {   'chirp_raw_traces': numpy.ndarray(shape=(113, 1538)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(113, 1538)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(113, 1538)),
#                                        'chirp_spikes': numpy.ndarray(shape=(113, 1538)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(113, 1538)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(113, 10)),
#                                        'date': '2021-09-29',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL4',
#                                        'group_assignment': numpy.ndarray(shape=(113,)),
#                                        'group_confidences': numpy.ndarray(shape=(113, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(113, 1014)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(113, 1014)),
#                                        'mb_spike_times': numpy.ndarray(shape=(113, 1014)),
#                                        'mb_spikes': numpy.ndarray(shape=(113, 1014)),
#                                        'mb_traces_times': numpy.ndarray(shape=(113, 1014)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(113, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(113, 5103)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(113, 5103)),
#                                        'natural_spike_times': numpy.ndarray(shape=(113, 5103)),
#                                        'natural_spikes': numpy.ndarray(shape=(113, 5103)),
#                                        'natural_traces_times': numpy.ndarray(shape=(113, 5103)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(113, 123)),
#                                        'responses_final': numpy.ndarray(shape=(113, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(113,)),
#                                        'scan_sequence_idx': 19,
#                                        'stim_id': 5},
#     'session_6_ventral2_20210921': {   'chirp_raw_traces': numpy.ndarray(shape=(93, 1559)),
#                                        'chirp_smoothed_traces': numpy.ndarray(shape=(93, 1559)),
#                                        'chirp_spike_times': numpy.ndarray(shape=(93, 1559)),
#                                        'chirp_spikes': numpy.ndarray(shape=(93, 1559)),
#                                        'chirp_traces_times': numpy.ndarray(shape=(93, 1559)),
#                                        'chirp_trigger_times': numpy.ndarray(shape=(93, 10)),
#                                        'date': '2021-09-21',
#                                        'exp_num': 2,
#                                        'experimenter': 'Szatko',
#                                        'eye': 'right',
#                                        'field': 'GCL5',
#                                        'group_assignment': numpy.ndarray(shape=(93,)),
#                                        'group_confidences': numpy.ndarray(shape=(93, 46)),
#                                        'mb_raw_traces': numpy.ndarray(shape=(93, 1034)),
#                                        'mb_smoothed_traces': numpy.ndarray(shape=(93, 1034)),
#                                        'mb_spike_times': numpy.ndarray(shape=(93, 1034)),
#                                        'mb_spikes': numpy.ndarray(shape=(93, 1034)),
#                                        'mb_traces_times': numpy.ndarray(shape=(93, 1034)),
#                                        'mb_trigger_times': numpy.ndarray(shape=(93, 24)),
#                                        'natural_raw_traces': numpy.ndarray(shape=(93, 5172)),
#                                        'natural_smoothed_traces': numpy.ndarray(shape=(93, 5172)),
#                                        'natural_spike_times': numpy.ndarray(shape=(93, 5172)),
#                                        'natural_spikes': numpy.ndarray(shape=(93, 5172)),
#                                        'natural_traces_times': numpy.ndarray(shape=(93, 5172)),
#                                        'natural_trigger_times': numpy.ndarray(shape=(93, 123)),
#                                        'responses_final': numpy.ndarray(shape=(93, 18450)),
#                                        'roi_coords': numpy.ndarray(shape=(0,)),
#                                        'roi_ids': numpy.ndarray(shape=(93,)),
#                                        'scan_sequence_idx': 10,
#                                        'stim_id': 5}}

# %%
np.isnan(stim_dataloaders_dict["session_4_ventral2_20200303"]["responses_final"]).any()
# Out:
# False

# %%
np.isnan(stim_dataloaders_dict["session_4_ventral2_20200303"]["natural_spikes"]).any()
# Out:
# True

# %%
# Visualise upsampling of the stimulus

plt.plot(
    stim_dataloaders_dict["session_4_ventral2_20200303"]["natural_traces_times"][
        0, :500
    ],
    stim_dataloaders_dict["session_4_ventral2_20200303"]["natural_spikes"][0, :500],
)
triggertimes = stim_dataloaders_dict["session_4_ventral2_20200303"][
    "natural_trigger_times"
][0]
upsampled_triggertimes = [np.linspace(t, t + 4.9666667, 5 * 30) for t in triggertimes]
upsampled_triggertimes = np.concatenate(upsampled_triggertimes)
plt.plot(
    upsampled_triggertimes[:500],
    stim_dataloaders_dict["session_4_ventral2_20200303"]["responses_final"][0, :500],
    marker="o",
    linestyle="None",
)

# %%
movies_dict.keys()
# Out:
# dict_keys(['eye', 'train', 'test', 'random_sequences'])

# %%
dataloaders = natmov_dataloaders_v2(stim_dataloaders_dict, movies_dict, seed=1000)
model = SFB3d_core_SxF3d_readout(**model_config, dataloaders=dataloaders, seed=42)
# Out:
# {'session_1_ventral1_20200226': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 131])}, 'session_1_ventral1_20200528': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 105])}, 'session_1_ventral1_20200707': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 171])}, 'session_1_ventral1_20201021': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 133])}, 'session_1_ventral1_20201030': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 105])}, 'session_1_ventral1_20210929': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 120])}, 'session_1_ventral1_20210930': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 107])}, 'session_1_ventral2_20200302': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 121])}, 'session_1_ventral2_20200707': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 159])}, 'session_1_ventral2_20201021': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 126])}, 'session_1_ventral2_20201022': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 133])}, 'session_1_ventral2_20201030': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 125])}, 'session_1_ventral2_20201117': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 114])}, 'session_1_ventral2_20210910': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 122])}, 'session_1_ventral2_20210921': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 109])}, 'session_1_ventral2_20210929': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 133])}, 'session_1_ventral2_20210930': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 112])}, 'session_1_ventral2_20211130': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 120])}, 'session_2_ventral1_20200226': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 120])}, 'session_2_ventral1_20200303': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 131])}, 'session_2_ventral1_20200528': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 93])}, 'session_2_ventral1_20200529': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 92])}, 'session_2_ventral1_20200701': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 146])}, 'session_2_ventral1_20201021': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 130])}, 'session_2_ventral1_20201030': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 132])}, 'session_2_ventral1_20210929': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 125])}, 'session_2_ventral2_20200303': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 125])}, 'session_2_ventral2_20201016': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 116])}, 'session_2_ventral2_20201021': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 115])}, 'session_2_ventral2_20201022': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 137])}, 'session_2_ventral2_20201030': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 143])}, 'session_2_ventral2_20201117': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 137])}, 'session_2_ventral2_20210910': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 115])}, 'session_2_ventral2_20210921': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 108])}, 'session_2_ventral2_20210929': {'inputs': torch.Size([32, 2, 50, 18, 16]), 'targets': torch.Size([32, 50, 99])}, 'session_2_v ...
# Random seed 42 has been set.
# /Projects/open-retina/openretina/hoefling_2022_models.py:822: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3637.)
#   return mask.T

# %%
test_score, val_score, output, model_state = trainer(
    model=model,
    dataloaders=dataloaders,
    seed=1000,
    **trainer_config,
    wandb_logger=None,
)
# Out:
# Random seed 1000 has been set.
# /home/bethge/bkr738/.local/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Epochs:   0%|          | 0/500 [00:00<?, ?it/s]

# %%
test_score
# Out:
# 0.459370441114146

# %%
val_score
# Out:
# 0.2753219876779971

# %%
plt.plot(output["val_correlation"])

# %%
val_field = "session_2_ventral1_20200303"
val_sample = next(iter(dataloaders["validation"][val_field]))

# %%
input_samples = val_sample.inputs
targets = val_sample.targets

# %%
input_samples.shape
# Out:
# torch.Size([15, 2, 150, 18, 16])

# %%
with torch.no_grad():
    reconstructions = model(input_samples.to("cuda:0"), val_field)

# %%
reconstructions = reconstructions.cpu().numpy().squeeze()
targets = targets.cpu().numpy().squeeze()

# %%
targets.shape
# Out:
# (15, 150, 131)

# %%
reconstructions.shape
# Out:
# (15, 120, 131)

# %%
# Your existing code for plotting
neuron = 1
fig, axes = plt.subplots(3, 5, figsize=(20, 5), sharey="row", sharex="col")
for trace_chunk in range(targets.shape[0]):
    ax_idx_1 = trace_chunk // 5
    ax_idx_2 = trace_chunk % 5
    ax = axes[ax_idx_1, ax_idx_2]
    ax.plot(targets[trace_chunk, 30:, neuron], label="target")
    ax.plot(reconstructions[trace_chunk, :, neuron], label="prediction")

    # Set x and y labels for only outer subplots
    if ax_idx_1 == 2:  # Bottom row
        ax.set_xlabel("Frames")
    if ax_idx_2 == 0:  # Leftmost column
        ax.set_ylabel("Firing rate")

    # # Remove inner labels
    # if ax_idx_1 != 2:
    #     ax.set_xticklabels([])
    # if ax_idx_2 != 0:
    #     ax.set_yticklabels([])
    # Only turn on x-axis labels for the bottom row
    if ax_idx_1 == 2:
        ax.tick_params(labelbottom=True)
    else:
        ax.tick_params(labelbottom=False)

    # Only turn on y-axis labels for the leftmost column
    if ax_idx_2 == 0:
        ax.tick_params(labelleft=True)
    else:
        ax.tick_params(labelleft=False)

# Place the legend outside of the subplots
axes[0, 0].legend()

sns.despine()

plt.tight_layout()
